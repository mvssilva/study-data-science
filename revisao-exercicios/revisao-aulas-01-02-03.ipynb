# %% [markdown]
# Tentando decifrar se uma senha de 4 digitos é boa ou não.

# %%
senhas = ["1234", "9876", "0147", "1111"]
# Out:
# A senha 1234 é perigosa!
# A senha 9876 é perigosa!
# A senha 0147 é perigosa!
# A senha 1111 é perigosa!
