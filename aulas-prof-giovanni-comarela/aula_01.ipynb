# %% [markdown]
# #Introdução e regras do jogo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Pragmática

# %% [markdown]
# ## Professor

# %% [markdown]
# **Nome:** Giovanni Comarela
#
# **e-mail:** gc@inf.ufes.br
#
# **sala:** 06, CT7

# %% [markdown]
# ## Disciplina

# %% [markdown]
# **Nomes reais:**
# - Introdução à Ciência de Dados, Turmas 1 e 2 (Graduação)
# - Ciência de Dados (Pós - Mestrado e Doutorado)
#
# **Nome na prática:**
# - Introdução à Ciência de Dados

# %% [markdown]
# ##O curso será centralizado no AVA

# %% [markdown]
# https://ava.ufes.br/course/view.php?id=17634

# %% [markdown]
# ## Sobre as aulas

# %% [markdown]
# - Ambiente participativo e interativo
# - Aulas são planejadas assumindo que haverá perguntas
# - Todas as perguntas são bem-vindas (até perguntas "idiotas")
# - Não há tolerância para:
#   - Destratar, diminuir ou depreciar uma pessoa tirando dúvida
#   - Qualquer tipo de discriminação

# %% [markdown]
# ## Sobre as dúvidas

# %% [markdown]
# - Durante as aulas
# - Pelo fórum de dúvidas do AVA
# - NÃO tiro dúvidas (sobre conteúdo) por e-mail

# %% [markdown]
# ## Monitor

# %% [markdown]
# - Athus Cavalini (Doutorado PPGI)
# - Dúvidas com o monitor devem ser tiradas pelo AVA

# %% [markdown]
# ## Sobre presença

# %% [markdown]
# Obrigatória!

# %% [markdown]
# ## Sobre colaboração indevida

# %% [markdown]
# Não paguem para ver...
#
# Isso inclui o uso de LLMs.

# %% [markdown]
# ## O que veremos?

# %% [markdown]
# Vide cronograma e plano de ensino (Cadastrados no Portal do Aluno -- Graduação)

# %% [markdown]
# ## Avaliação

# %% [markdown]
# Teremos:
# - Algumas listas de exercícios, valendo um total de 3 pontos
# - Um trabalho prático, valendo 3 pontos
#   - trabalho fechado. Vou fornecer um conjunto de dados e uma metodologia/objetivo
#
# - Um projeto final, valendo 4 pontos
#   - trabalho de escopo aberto. Vocês vão propor um tema/problema, vão propor uma solução e analisar os resultados
#
# Aos alunos da pós:
# - As listas terão exercícios mais difíceis
# - A correção do trabalho pratico e do projeto final será diferente e vou exigir (muito) mais de vocês.

# %% [markdown]
# ## Pré-requisitos

# %% [markdown]
# - Um bom curso de algoritmos e EDs
# - Um curso de Álgebra Linear
# - Um curso de Estatística/Probabilidade
# - Saber ou estar estudando Python

# %% [markdown]
# # Ciência de Dados

# %% [markdown]
# ##O que é?

# %% [markdown]
# É uma área de trabalho/pesquisa cujos problemas são orientados a dados.
#
# Na verdade, é um termo cunhado para várias coisas que já existiam.
#
# **Perguntas comuns são:**
#
# 1. Tenho um conjunto de dados, o que posso dizer de útil sobre ele?
#
# 2. Tenho uma hipótese, que tipo de dados preciso coletar e quais algoritmos preciso usar para validar (ou não) essa hipótese?
#
# 3. Se um conjunto de dados, $X$, tem uma propriedade, $Y$, quais são os algoritmos que preciso para responder uma pergunta, $Z$, sobre $X$?
#
# 4. ...

# %% [markdown]
# ## O que um/a cientista de dados precisa saber?

# %% [markdown]
# Computação:
# - Programação
# - Algoritmos
# - Sistemas de Computação
# - Inteligência Artificial
# - Aprendizado de Máquina
#
# Estatística:
# - Análise exploratória de dados
# - Probabilidade
# - Inferência estatística
#
# Matemática:
# - Álgebra Linear
# - Cálculo de várias variáveis
# - Otimização convexa

# %% [markdown]
# ## Qual a diferença entre Ciência de dados, estatística, aprendizado de máquina, mineração de dados e inteligência artificial?

# %% [markdown]
# Para os puristas, há muita! Na prática...
#
# Preocupem-se com os problemas e em encontrar as ferramentas corretas para abordá-los!

# %% [markdown]
# ## Como está o mercado?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Objetivos do curso

# %% [markdown]
# 1. O objetivo desse curso não é ensinar Python nem bibliotecas Python
#
# 2. Se você souber as **propriedades** do conjunto de dados e o **algoritmo** que precisa usar, você consegue encontrar um exemplo de código útil no Google
#
# 3. Nesse curso, estudaremos métodos, pressupostos e interpretação de resultados
#
# 4. Vocês vão aprender o que precisam se perguntar e com o que precisam se preocupar antes de abordarem um problema orientado a dados. A ideia é que possam generalizar o que aprenderem aqui
#
# 5. Nem de longe veremos tudo que um/a Cientista de Dados precisa saber. Tentei escolher tópicos em diversas áreas para passar uma visão geral...

# %% [markdown]
# ## Qual o grau de formalismo das aulas?

# %% [markdown]
# - Vai depender bastante do tema
# - Seria necessário que vocês soubessem mais **estatística** e **álgebra linear** em muitas situações
# - Vamos construir alguns algoritmos. Mas na maior parte dos casos, veremos apenas a intuição de como funcionam
# - Não discutiremos aspectos de implementação. Uma vez que entendermos o método, usaremos bibliotecas do Python

# %% [markdown]
# # Aquecimento

# %% [markdown]
# Exemplo extraído da página https://www.datagenetics.com/blog/september32012/

# %% [markdown]
# ## Perguntas

# %% [markdown]
# - Como as pessoas escolhem senhas de cartões de crédito?
#
# - Quais são as senhas mais populares?
#
# - É possível explicar as senhas mais populares?

# %% [markdown]
# ## Conjunto de dados

# %% [markdown]
# - Uma base de dados de senhas de cartões dos Estados Unidos
#
# - Cartões de crédito nos Estados Unidos têm 4 dígitos
#
# - Os dados não estão disponíveis. Tudo que eu apresentar aqui foi extraído/copiado da página citada
#
# - "*Obviously, I don’t have access to a credit card PIN number database. Instead I’m going to use a proxy. I’m going to use data condensed from released/exposed/discovered password tables and security breaches.*"

# %% [markdown]
# ## Metodologia

# %% [markdown]
# ### Mapa de Calor

# %% [markdown]
# Uma matriz pode ser visualizada por meio de um mapa de calor

# %%
import numpy as np
from matplotlib import pyplot as plt

X = np.array([[1,2,3,4],[5,6,7,8],[5,6,7,8],[4,3,2,1]])
X
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8],
#        [5, 6, 7, 8],
#        [4, 3, 2, 1]])

# %%
plt.imshow(X, cmap = 'hot', origin = 'lower')
plt.xticks([0, 1, 2, 3], ['0', '1', '2', '3'])
plt.yticks([0, 1, 2, 3], ['0', '1', '2', '3'])
plt.xlabel('Índice da coluna')
plt.ylabel('Índice da linha')
_ = plt.colorbar()

# %% [markdown]
# ### Representação visual dos dados

# %% [markdown]
# O que o autor do artigo fez foi o seguinte. Ele criou uma matriz $\mathbf{X}$ com a seguinte propriedade:
# - Dada uma senha de quatro dígitos $abcd$,
#   - $\mathbf{X}[cd, ab]$ conta a frequência da senha $abcd$.
# - Exemplo: o elemento na coluna $12$ e linha $34$ conta quantas vezes a senha $1234$ aparece no conjunto de dados.
#
# Assim, a matriz de interesse tem 100 linhas e 100 colunas.

# %% [markdown]
# ### Exemplo

# %%
X = np.array([[10,7,3,4],[5,10,2,4],[2,1,10,0],[0,4,2,10]])
X
# Out:
# array([[10,  7,  3,  4],
#        [ 5, 10,  2,  4],
#        [ 2,  1, 10,  0],
#        [ 0,  4,  2, 10]])

# %%
plt.imshow(X, cmap = 'hot', origin = 'lower')
plt.xticks([0, 1, 2, 3], ['00', '01', '02', '03'])
plt.yticks([0, 1, 2, 3], ['00', '01', '02', '03'])
plt.xlabel('Dois primeiros dígitos')
plt.ylabel('Dois últimos dígitos')
_ = plt.colorbar()

# %% [markdown]
# ## Resultados

# %% [markdown]
# O resultado principal do artigo consiste de um único gráfico

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Primeiro, vamos ter certeza que entendemos o gráfico
# - **Eixo $x$** representa os dois **primeiros** dígitos da senha
# - **Eixo $y$** representa os dois **últimos** dígitos da senha
# - Quanto mais clara for uma entrada da imagem, mais frequente é a senha relacionada

# %% [markdown]
# ### Interpretação

# %% [markdown]
# #### Parte I - Diagonal principal

# %% [markdown]
# Senhas do tipo $xyxy$, ou seja, fáceis de lembrar

# %% [markdown]
# #### Parte II - Coluna vertical mais clara

# %% [markdown]
# Senhas do tipo $19xy$, ou seja, datas de nascimento
#
# Veja que o início da coluna $20xy$ tem o mesmo comportamento

# %% [markdown]
# #### Parte III - Retângulo na parte inferior-esquerda

# %% [markdown]
# Senhas do tipo $abcd$ com $ab \le 12$ e $cd \le 31$.
#
# Representam datas, lembrando que nos EUA, usam o padrão MM/DD.

# %% [markdown]
# #### Parte IV - Alguns exemplos específicos (pontos claros na figura)

# %% [markdown]
# - 1234
# - 0987
# - 4321
# - 2345
# - 2468
# - 5678
# - 7890
# - 2580

# %% [markdown]
# ### Conclusão

# %% [markdown]
# #### Parte I

# %% [markdown]
# Em geral, somos "preguiçosos" na hora de escolher senhas. Temos a tendência de escolher senhas fáceis de lembrar ou senhas que nos lembram de elementos importantes em nossas vidas.

# %% [markdown]
# #### Parte II

# %% [markdown]
# Essa conclusão foi possibilitada pela escolha da metodologia. Não pela escolha de uma LP ou mesmo por bibliotecas específicas. Nada muito complexo/elaborado foi empregado.
#
# Esse é o tipo de conhecimento que eu espero que vocês ganhem ao longo do semestre. O difícil é saber o que programar, não como programar (já tem biblioteca pra quase tudo).

# %% [markdown]
# #### Parte III

# %% [markdown]
# Em resumo, e isso vale para muitas disciplinas e situações, esse vai ser um curso que vai ensinar a vocês como escrever boas consultas no Google...
